# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#every features data is in number and species is in values
df['species'].unique()
#species hi predict karni hai
# Out:
# <ArrowStringArray>
# ['setosa', 'versicolor', 'virginica']
# Length: 3, dtype: str

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('species',axis=1)
y = df['species']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
#we will use knn model
from sklearn.neighbors import KNeighborsClassifier

# %%
model_knn = KNeighborsClassifier(n_neighbors=5)

# %%
model_knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
model_knn.score(X_test,y_test)
# Out:
# 0.98

# %%
#if you are getting an accuracy 100% it means your model is going overfit 
#if you chnage parameters and it will affect your accuracy

# %%
#no we will use svm to get accuracy
from sklearn.svm import SVC

# %%
model_svm = SVC(gamma='auto')
#c is a punishment to points who are near boundary

# %%
model_svm.fit(X_train,y_train)
# Out:
# SVC(C=30, gamma='auto')

# %%
model_svm.score(X_test,y_test)
# Out:
# 0.98

# %%
#if we change c, accuracy score will also get change so thats why we will use
#grid seeacrh cv
#it helps the model to avoid overfit

# %%
from sklearn.model_selection import GridSearchCV

# %%
classifier = GridSearchCV((model_svm),{
    'C':[1,10,20,30],
    'kernel':['rbf','linear']
}, cv=5,return_train_score=False) 

#classifier is a hyperparameter tuning variable
#estimator is model_svm

# %%
classifier.fit(X,y)
# Out:
# GridSearchCV(cv=5, estimator=SVC(gamma='auto'),
#              param_grid={'C': [1, 10, 20, 30], 'kernel': ['rbf', 'linear']})

# %%
classifier.cv_results_
# Out:
# {'mean_fit_time': array([0.00499172, 0.00232296, 0.00178752, 0.00185404, 0.00186563,
#         0.00176773, 0.00228953, 0.00175004]),
#  'std_fit_time': array([0.00147772, 0.00102621, 0.00027048, 0.0004101 , 0.00051665,
#         0.00023949, 0.00065741, 0.00018193]),
#  'mean_score_time': array([0.00332766, 0.00127635, 0.00146289, 0.00149431, 0.00132656,
#         0.0014173 , 0.00194702, 0.0016304 ]),
#  'std_score_time': array([0.00200075, 0.0001233 , 0.00051814, 0.00047154, 0.00031605,
#         0.00045944, 0.00102377, 0.00078101]),
#  'param_C': masked_array(data=[1, 1, 10, 10, 20, 20, 30, 30],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value=999999),
#  'param_kernel': masked_array(data=['rbf', 'linear', 'rbf', 'linear', 'rbf', 'linear',
#                     'rbf', 'linear'],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value=np.str_('?'),
#              dtype=object),
# ...

# %%
results = pd.DataFrame(classifier.cv_results_)

# %%
results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       0.004992      0.001478         0.003328        0.002001        1
# 1       0.002323      0.001026         0.001276        0.000123        1
# 2       0.001788      0.000270         0.001463        0.000518       10
# 3       0.001854      0.000410         0.001494        0.000472       10
# 4       0.001866      0.000517         0.001327        0.000316       20
# 5       0.001768      0.000239         0.001417        0.000459       20
# 6       0.002290      0.000657         0.001947        0.001024       30
# 7       0.001750      0.000182         0.001630        0.000781       30
#
#   param_kernel                         params  split0_test_score  \
# 0          rbf      {'C': 1, 'kernel': 'rbf'}           0.966667
# 1       linear   {'C': 1, 'kernel': 'linear'}           0.966667
# 2          rbf     {'C': 10, 'kernel': 'rbf'}           0.966667
# ...

# %%
results[['param_C','param_kernel','mean_test_score']] #param is parameter
# Out:
#    param_C param_kernel  mean_test_score
# 0        1          rbf         0.980000
# 1        1       linear         0.980000
# 2       10          rbf         0.980000
# 3       10       linear         0.973333
# 4       20          rbf         0.966667
# 5       20       linear         0.966667
# 6       30          rbf         0.960000
# 7       30       linear         0.960000

# %%
#thats means if your param_cv and kernel it will give best mean test score

# %%
#now we will use random search cv
from sklearn.model_selection import RandomizedSearchCV

# %%
classifier_r = RandomizedSearchCV((model_svm),{
    'C':[1,10,20,30],
    'kernel':['rbf','linear']
},n_iter = 4 ,cv=5,return_train_score=False)

# %%
classifier_r.fit(X,y)
# Out:
# RandomizedSearchCV(cv=5, estimator=SVC(gamma='auto'), n_iter=4,
#                    param_distributions={'C': [1, 10, 20, 30],
#                                         'kernel': ['rbf', 'linear']})

# %%
results2 = pd.DataFrame(classifier_r.cv_results_)

# %%
results2[['param_C','param_kernel','mean_test_score']]
# Out:
#    param_C param_kernel  mean_test_score
# 0       10       linear         0.973333
# 1        1       linear         0.980000
# 2       20       linear         0.966667
# 3        1          rbf         0.980000
